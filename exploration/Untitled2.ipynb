# %%
import pandas as pd
df = pd.read_pickle("../data/AUD_JPY_H1.pkl")
print("Loaded DataFrame columns:", df.columns)
df.head()
# Out:
# Loaded DataFrame columns: Index(['time', 'volume', 'mid_o', 'mid_h', 'mid_l', 'mid_c', 'bid_o', 'bid_h',
#        'bid_l', 'bid_c', 'ask_o', 'ask_h', 'ask_l', 'ask_c'],
#       dtype='object')
#                        time  volume   mid_o   mid_h   mid_l   mid_c   bid_o  \
# 0 2016-01-07 00:00:00+00:00    1515  83.968  84.056  83.854  83.920  83.956
# 1 2016-01-07 01:00:00+00:00    7752  83.922  84.130  82.660  82.856  83.914
# 2 2016-01-07 02:00:00+00:00    4280  82.858  83.182  82.803  83.030  82.841
# 3 2016-01-07 03:00:00+00:00    2370  83.032  83.308  82.976  83.296  83.021
# 4 2016-01-07 04:00:00+00:00    1567  83.294  83.401  83.056  83.059  83.283
#
#     bid_h   bid_l   bid_c   ask_o   ask_h   ask_l   ask_c
# 0  84.044  83.842  83.909  83.980  84.081  83.867  83.931
# 1  84.112  82.640  82.837  83.931  84.147  82.679  82.874
# 2  83.169  82.788  83.019  82.876  83.200  82.817  83.041
# 3  83.296  82.964  83.284  83.043  83.321  82.989  83.307
# ...

# %%
import sys
sys.path.append('../')
from plotting import CandlePlot
import pandas as pd
from technicals.indicators import BollingerBands

# %%
df = pd.read_pickle("../data/AUD_CAD_H1.pkl")

# %%
df_an = df.copy()
df_an =BollingerBands(df, n=40, s=3)

# %%
cp = CandlePlot(df_an.iloc[-200:], candles = True)
cp.show_plot(line_traces=['BB_MA', 'BB_UP', 'BB_LW'])
